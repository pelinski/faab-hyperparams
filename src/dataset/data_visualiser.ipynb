# %%
from dataset import Dataset
import matplotlib.pyplot as plt
import random

dataset = Dataset().load_dataset_from_pickle('data/07041536/processed_512.pkl')

# %%
dataset.inputs.shape
# Out:
# torch.Size([90450, 512, 8])

# %%
fig, axs = plt.subplots(4, 2, figsize=(15, 15))
for i, ax in enumerate(axs.flat):
    ax.plot(random.choice(dataset.inputs)[:,i])
    ax.set_title(dataset.feature_names[i])
plt.show()

# %%
import torch
torch.isnan(dataset.inputs).any()
# Out:
# tensor(False)

# %%
from dataset import DatasetPred

dataset = DatasetPred().load_dataset_from_pickle('processed_dataset_pred.pkl')

# %%
dataset.targets.size()
# Out:
# torch.Size([103366, 128, 8])

# %%
dataset.inputs.size()
# Out:
# torch.Size([103367, 128, 8])

# %%
dataset.inputs.mean()
# Out:
# tensor(0.0062)
